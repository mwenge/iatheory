# %%
s = """
$00,$03,$06,$08,$00,$0C,$04,$08
$00,$07,$00,$05,$05,$00,$00,$05
$00,$06,$09,$05,$02,$04,$03,$04
$03,$07,$03,$00,$04,$08,$0C,$09
$07,$08,$04,$07,$00,$04,$07,$0E
$00,$00,$00,$07,$07,$04,$00,$0C
$04,$07,$00,$0C,$07,$08,$0A,$08
$0C,$00,$0C,$03,$0C,$03,$07,$00
"""
bs = s.replace('\n',',').split(',')
len(set(bs))
# Out:
# 13

# %%
l = []
for i in range(0,16):
    l += [(i*4)]
len(l)
# Out:
# 16

# %%
for no in range(7,81):
    fig = f"""
\\begin{{figure}}[H]
{{
  \\begin{{adjustbox}}{{width=11cm,center}}
  \\includegraphics[width=11cm]{{music/title_no_{no}_page_1001.png}}%
    \\end{{adjustbox}}
}}
\\end{{figure}}
"""
    print(fig)
# Out:
# \begin{figure}[H]
# {
#   \begin{adjustbox}{width=11cm,center}
#   \includegraphics[width=11cm]{music/title_no_7_page_1001.png}%
#     \end{adjustbox}
# }
# \end{figure}
#
#
# \begin{figure}[H]
# {
#   \begin{adjustbox}{width=11cm,center}
#   \includegraphics[width=11cm]{music/title_no_8_page_1001.png}%
#     \end{adjustbox}
# }
# \end{figure}
#
#
# \begin{figure}[H]
# {
#   \begin{adjustbox}{width=11cm,center}
#   \includegraphics[width=11cm]{music/title_no_9_page_1001.png}%
#     \end{adjustbox}
# }
# \end{figure}
#
#
# \begin{figure}[H]
# {
#   \begin{adjustbox}{width=11cm,center}
#   \includegraphics[width=11cm]{music/title_no_10_page_1001.png}%
#     \end{adjustbox}
# }
# \end{figure}
#
#
# \begin{figure}[H]
# {
#   \begin{adjustbox}{width=11cm,center}
#   \includegraphics[width=11cm]{music/title_no_11_page_1001.png}%
#     \end{adjustbox}
# }
# \end{figure}
#
#
# \begin{figure}[H]
# {
#   \begin{adjustbox}{width=11cm,center}
# ...

# %%
for no in range(7,81,2):
    fig = f"""
\\begin{{figure}}[H]                                             
{{                                                             
  \setlength{{\\tabcolsep}}{{3.0pt}}                               
  \setlength\cmidrulewidth{{\heavyrulewidth}} % Make cmidrule = 
  \\begin{{subfigure}}{{0.5\\textwidth}}                            
  \includegraphics[width=6cm]{{music/title_no_{no}_page_1001.png}}%
  \end{{subfigure}}                                             
  \\begin{{subfigure}}{{0.5\\textwidth}}                            
  \includegraphics[width=6cm]{{music/title_no_{no+1}_page_1001.png}}%
  \end{{subfigure}}                                             
}}                                                             
\end{{figure}}                                                  
"""
    print(fig)
# Out:
# \begin{figure}[H]
# {
#   \setlength{\tabcolsep}{3.0pt}
#   \setlength\cmidrulewidth{\heavyrulewidth} % Make cmidrule =
#   \begin{subfigure}{0.5\textwidth}
#   \includegraphics[width=6cm]{music/title_no_7_page_1001.png}%
#   \end{subfigure}
#   \begin{subfigure}{0.5\textwidth}
#   \includegraphics[width=6cm]{music/title_no_8_page_1001.png}%
#   \end{subfigure}
# }
# \end{figure}
#
#
# \begin{figure}[H]
# {
#   \setlength{\tabcolsep}{3.0pt}
#   \setlength\cmidrulewidth{\heavyrulewidth} % Make cmidrule =
#   \begin{subfigure}{0.5\textwidth}
#   \includegraphics[width=6cm]{music/title_no_9_page_1001.png}%
#   \end{subfigure}
#   \begin{subfigure}{0.5\textwidth}
#   \includegraphics[width=6cm]{music/title_no_10_page_1001.png}%
#   \end{subfigure}
# }
# \end{figure}
#
#
# \begin{figure}[H]
# {
#   \setlength{\tabcolsep}{3.0pt}
#   \setlength\cmidrulewidth{\heavyrulewidth} % Make cmidrule =
#   \begin{subfigure}{0.5\textwidth}
# ...
